# %% [markdown]
# Ways to Clean and Transform Data using MEASURES OF SPREAD

# %%
#World Bank data, 2016 version
WB <- read.csv("https://raw.githubusercontent.com/jreuning/sds230_data/refs/heads/main/WB.2016.csv", header = T, as.is = T)

# %%
#Make a boxplot - try changing horizontal = TRUE
boxplot(WB$Fertility16, 
        horizontal = TRUE,
        col = 'yellow',
        main = "Boxplot of Fertility Rate 2016", 
        xlab = "Fertility Rate 2016")
#add mean
points(mean(WB$Fertility16, na.rm = T), pch = 19, col = 'red', cex = 2)
# Out:
# Plot with title “Boxplot of Fertility Rate 2016”

# %% [markdown]
# Let's compare how a boxplot and a histogram look for the same data

# %%
#For comparison, let's look at a corresponding histogram
hist(WB$Fertility16, 
        col = 'yellow',
        main = "Boxplot of Fertility Rate 2016", 
        xlab = "Fertility Rate 2016")
#add line at the mean
abline(v = mean(WB$Fertility16, na.rm = T), col = 'red', lwd = 3)
abline(v = median(WB$Fertility16, na.rm = T), col = 'black', lwd = 3)
legend("topright", c("mean", "median"), col = c("red", "black"), lwd = 3)
# Out:
# Plot with title “Boxplot of Fertility Rate 2016”

# %% [markdown]
# Roundup Data

# %%
#get data
roundup <- read.csv("https://raw.githubusercontent.com/jreuning/sds230_data/refs/heads/main/RoundUp.csv", header = T)
#look at data
roundup
# Out:
#    Species   Concentration Dry.Weight
# 1  Radish    0.00          0.8019
# 2  Radish    0.00          1.9457
# 3  Radish    0.00          1.6644
# 4  Radish    0.10          1.8613
# 5  Radish    0.10          1.2914
# 6  Radish    0.10          1.2735
# 7  Radish    0.25          0.4617
# 8  Radish    0.25          0.4858
# 9  Radish    0.25          0.8380
# 10 Radish    0.50          0.3650
# 11 Radish    0.50          0.3118
# 12 Radish    0.50          0.2169
# 13 Radish    1.00          0.2064
# 14 Radish    1.00          0.2032
# 15 Radish    1.00          0.1471
# 16 Rye Grass 0.00          1.5963
# 17 Rye Grass 0.00          0.9778
# 18 Rye Grass 0.00          1.9583
# 19 Rye Grass 0.10          0.5504
# 20 Rye Grass 0.10          0.4977
# 21 Rye Grass 0.10          1.0528
# 22 Rye Grass 0.25          0.1396
# 23 Rye Grass 0.25          0.2444
# 24 Rye Grass 0.25          0.0343
# 25 Rye Grass 0.50          0.0171
# 26 Rye Grass 0.50          0.0290
# 27 Rye Grass 0.50          0.0354
# 28 Rye Grass 1.00          0.0045
# 29 Rye Grass 1.00          0.0013
# 30 Rye Grass 1.00          0.0195

# %%
#make dataset that is just radishes
radish <- roundup[roundup$Species == "Radish", ]
table(radish$Concentration)
# Out:
#    0  0.1 0.25  0.5    1
#    3    3    3    3    3

# %%
#Make boxplot by concentration
boxplot(radish$Dry.Weight ~ radish$Concentration,
        col = 'red',
        main = "Radish Dry Weight vs Concentration", 
        xlab = "Round-Up Concentration", 
        ylab = "Dry Weight")
# Out:
# Plot with title "Radish Dry Weight vs Concentration"

# %% [markdown]
# Variance and Standard Deviation

# %%
#We look at World Bank Data
var(WB$Fertility16)
WB$Fertility16
# Out:
# [1] NA
#   [1] 4.635 1.713 2.776    NA    NA 5.694 2.051 2.293 1.612 1.800 1.809 1.490
#  [13] 1.940 1.767 2.033 2.104 1.797 1.733 1.700 2.510 4.977 1.610 2.051 2.878
#  [25] 1.360 2.730 1.726    NA 1.874 1.530 5.353 5.697 2.334 2.560 4.708 1.600
#  [37]    NA 4.869 5.947 1.478 1.774 1.624 1.853 4.347 6.112 4.661 1.783 4.911
#  [49] 1.400 1.722 1.700 1.343 1.570 1.710 2.847    NA 2.422 2.486 3.265 2.079
#  [61] 4.687 4.133 1.580 4.198 2.600 2.516 1.650 1.960 2.013 3.786 5.425 1.996
#  [73] 1.500 3.984    NA 1.330 2.000 2.104 2.347 2.973 4.855 4.633 2.510 2.919
#  [85] 2.462 1.205 1.450 1.800 2.326 2.363 1.661 4.370 1.920    NA 3.110 1.350
#  [97] 2.009 1.440 3.378 2.730 3.852 3.651 1.910 1.172 2.060 1.970 3.100 2.698
# [109] 1.700 1.719 3.094 4.581 2.274 1.400 1.700 1.470 1.311 1.533 4.184 4.571
# [121] 2.037 2.093 6.057 1.450    NA 4.674 1.400 2.184 3.145 1.241    NA 2.757
# [133] 1.667 2.491 5.243 2.207 3.415    NA 2.118 1.660 2.080 1.870 2.200 7.239
# [145] 5.526    NA 1.720 2.666 3.481    NA 2.514 3.658 2.480 2.400 2.925 1.320
# [157] 1.310 1.300 1.907 1.580 1.750 3.885 3.976    NA 4.456 2.532 4.769 1.460
# [169] 2.780 4.457 1.200    NA 1.400 1.570 3.850 6.267 2.458 4.855 1.330 2.046
# [181]    NA 1.459 1.810 1.931 4.532 2.372 3.084 1.850 1.540 2.916 3.360 5.016
# [193] 1.482 5.503 4.450 3.636 1.752 2.201 2.053 2.888    NA    NA 5.591 1.466
# [205] 1.748 1.800 1.800 1.995 2.455 3.275 2.317 1.954 2.090 4.008 3.995 4.981
# [217] 3.760

# %%
#again, we have to deal with missing data
var(WB$Fertility16, na.rm = T)
# Out:
# [1] 1.761457

# %%
#round to make it easier to read
round(var(WB$Fertility16, na.rm = T), 2)
#get standard deviations
round(sd(WB$Fertility16, na.rm = T), 2)
# Out:
# [1] 1.76
# [1] 1.33

# %% [markdown]
# HANDY - get lots of summary statistics at once!

# %%
#Summary Statistics
summary(WB$Fertility16)
summary(WB$GunsPer100)
summary(WB$CO2)
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.    NA's
#   1.172   1.720   2.200   2.718   3.520   7.239      17
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.    NA's
#    0.50    6.25   10.55   15.17   21.70  101.05     147
#     Min.  1st Qu.   Median     Mean  3rd Qu.     Max.     NA's
#  0.04448  0.85229  2.76498  4.96800  6.21894 45.42324       13

# %% [markdown]
# You can do summaries by group

# %%
tapply(radish$Dry.Weight, radish$Concentration, summary)
# Out:
# $`0`
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#  0.8019  1.2331  1.6644  1.4707  1.8051  1.9457
#
# $`0.1`
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#   1.274   1.282   1.291   1.475   1.576   1.861
#
# $`0.25`
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#  0.4617  0.4738  0.4858  0.5952  0.6619  0.8380
#
# $`0.5`
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#  0.2169  0.2643  0.3118  0.2979  0.3384  0.3650
#
# $`1`
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#  0.1471  0.1752  0.2032  0.1856  0.2048  0.2064

# %%
#get variances
round(tapply(radish$Dry.Weight, radish$Concentration, var), 3)
#get standard deviations
round(tapply(radish$Dry.Weight, radish$Concentration, sd), 3)
# Out:
#     0   0.1  0.25   0.5     1
# 0.355 0.112 0.044 0.006 0.001
#     0   0.1  0.25   0.5     1
# 0.596 0.334 0.211 0.075 0.033

# %% [markdown]
# Let's look at various plots for CO2 emissions per capita

# %%
hist(WB$CO2, 
     col = "blue", 
     main = "Histogram of CO2 per capita", 
     xlab = "CO2 per capita", 
     ylab = "frequency")

boxplot(WB$CO2, 
     col = "blue", 
     horizontal = T,
     main = "Boxplot of CO2 per capita", 
     xlab = "CO2 per capita", 
     ylab = "frequency")
# Out:
# Plot with title "Histogram of CO2 per capita"
# Plot with title "Boxplot of CO2 per capita"
